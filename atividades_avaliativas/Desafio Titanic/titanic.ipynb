# %% [markdown]
# # Atividade: Resolver Titanic usando Keras
#
# Crie um modelo em Keras para resolver o problema Titanic no Kaggle.
#
# Use pipelines com scikit-learn.
#
# Sua nota será seu score seguindo a fórmula: (score-0,65)*150, limitado a 30 pontos.

# %%
import pandas as pd

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
X = train[list(test.columns)]
y = train[train.columns[~train.columns.isin(test.columns)]]

# %%
import warnings
warnings.filterwarnings('ignore')

X.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
#preencher NaN da Cabin com outro valor para utiliza-lo de outra forma
X.fillna(X.mean(), inplace=True)
test.fillna(test.mean(), inplace=True)

X.fillna("unknown", inplace=True)
test.fillna("unknown", inplace=True)

# %%
#extraindo mais caracteristicas
def extraiPronome(nome):
    return nome.split(',')[1].split('.')[0].strip()

def extraiSobrenome(name):
    return name.split(',')[0]

def extraiPrefixoCabine(cabine):
    if cabine == "unknown":
        return "Z" #categoria ficticia para os nao preenchidos
    return cabine[0]

#nova coluna com sobrenome
X["Pronome"] = X["Name"].apply(extraiPronome)
X["Sobrenome"] = X["Name"].apply(extraiSobrenome)
#X["Cabin"] = X["Cabin"].apply(extraiPrefixoCabine)

test["Pronome"] = test["Name"].apply(extraiPronome)
test["Sobrenome"] = test["Name"].apply(extraiSobrenome)
#test["Cabin"] = test["Cabin"].apply(extraiPrefixoCabine)

X.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500  unknown        S
# 1  female  38.0      1      0          PC 17599  71.2833      C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250  unknown        S
# 3  female  35.0      1      0            113803  53.1000     C123        S
# 4    male  35.0      0      0            373450   8.0500  unknown        S
#
#   Pronome  Sobrenome
# 0      Mr     Braund
# 1     Mrs    Cumings
# 2    Miss  Heikkinen
# 3     Mrs   Futrelle
# 4      Mr      Allen

# %% [markdown]
# A ideia foi extrair apenas o primeiro caracter do campo Cabin e verificar se isso ajuda na classificação. Além disso, o campo Sobrenome foi adicionado.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

def extraiPronome(nome):
    return nome.split(',')[1].split('.')[0].strip()

def extraiSobrenome(name):
    return name.split(',')[0]

def extraiPrefixoCabine(cabine):
    if cabine == "unknown":
        return "Z" #categoria ficticia para os nao preenchidos
    return cabine[0]

class AtributosDesejados(BaseEstimator, TransformerMixin):
    def __init__(self, excluirName=True, excluirCabin=False, excluirSobrenome=False):
        self.excluirName = excluirName
        self.excluirCabin = excluirCabin
        self.excluirSobrenome = excluirSobrenome
    def fit(self, X, y=None):
        #self.colunasIndesejadas = ['PassengerId', 'Ticket', 'Cabin']
        self.colunasIndesejadas = ['PassengerId', 'Ticket']
        if self.excluirName:
            self.colunasIndesejadas.append('Name')
        if self.excluirCabin:
            self.colunasIndesejadas.append('Cabin')
        if self.excluirSobrenome:
            self.colunasIndesejadas.append('Sobrenome')

        return self
    def transform(self, X, y=None):
        Xdrop = X.drop(self.colunasIndesejadas,axis=1)
        if 'Name' not in self.colunasIndesejadas:
            Xdrop['Name'] = Xdrop['Name'].apply(extraiPronome)
        
        if 'Cabin' not in self.colunasIndesejadas:
            Xdrop['Cabin'] = Xdrop['Cabin'].apply(extraiPrefixoCabine)
        return Xdrop

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class AtributosNumericos(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        self.colunasNumericas = X.select_dtypes(include='number').columns
        return self
    def transform(self, X, y=None):
        return X[self.colunasNumericas].to_numpy()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class AtributosCategoricos(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        self.colunasCategoricas = X.select_dtypes(include='object').columns
        return self
    def transform(self, X, y=None):
        return X[self.colunasCategoricas].to_numpy()

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline, FeatureUnion

trataAtributos = Pipeline([
    ('unecaracteristicas', FeatureUnion([
        ('pipenum', Pipeline([
            ('atributos_numericos', AtributosNumericos()),
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ])),
        ('pipecat', Pipeline([
            ('atributos_categoricos', AtributosCategoricos()),
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]))
    ])),
])

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_validate, RepeatedKFold

#classifier = RandomForestClassifier()
def TreinarPadrao(classifier):
    pipetotal = Pipeline([
        ('atributosDesejados', AtributosDesejados()),
        ('trataAtributos', trataAtributos),
        ('classificador', classifier) 
    ])

    parametros = {
        'atributosDesejados__excluirName': [True, False],
        'atributosDesejados__excluirCabin': [True],
        'atributosDesejados__excluirSobrenome': [True], #após alguns testes mantive as duas informações novas. Como demora muito, estou fizando em True
        'classificador__max_depth': [5]
    }

    modelo = GridSearchCV(pipetotal, param_grid=parametros)

    scores = cross_validate(modelo, X, y, cv=RepeatedKFold())
    scores['test_score'], np.mean(scores['test_score']), np.std(scores['test_score'])

# %%
#
def FitAndPrintModelToKaggle(modelo, X, y, fit=True):
    if fit:
        modelo.fit(X,y)
    
    y_pred = modelo.predict(test)
    result = test[['PassengerId']]
    result['Survived'] = y_pred
    result.to_csv('submission.csv',index=False)

# %% [markdown]
# ## Definição do MLP com Keras

# %% [markdown]
# ### Funções de plot
#
# As funções abaixo são úteis para testes cuja base de dados seja plotável para as acaracterísticas que se desejar.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import label_binarize

def plotDataSet(X,y):
    plt.xlabel('X1')
    plt.ylabel('X2')
    
    for k in set(y):
        #print("k=",k)
        plt.plot(X[:,0][y==k],
                 X[:,1][y==k],
                 "o",alpha=0.3)

def plotHiperplano(X,y,vetor, intercept=0):
    x0min = min(X[:,0])
    x0max = max(X[:,0])
    
    xs = np.linspace(x0min, x0max, num=2)
    #separador do hiperplano entre duas classificações pode ser 
    #encontrada conforme calculo abaixo:
    ys = (-vetor[0]/vetor[1])*xs-intercept/vetor[1]
    plt.plot(xs,ys)

def define_axes(X, margem=0.1):
    '''
    A função retorna os eixos com a margem de 0.1
    O vetor será o mínimo até o máximo de cada um; esses são os eixos em que faremos a distribuição.
    '''
    #o mínimo e máximo da característica 1
    min1 = X[:,0].min()
    max1 = X[:,0].max() 

    min2 = X[:,1].min()
    max2 = X[:,1].max() 

    #colocando margem para baixo e margem pra cima de 10%
    return [min1-margem, max1+margem, min2-margem, max2+margem] #margem idel é .1 é o mesmo que 0.1

def plotPredictions(clf, X):
    '''
    Recebe um classificador e a matriz de características e exibe um gráfico utilizando meshgrid.
    '''
    axes = define_axes(X)
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0,x1 = np.meshgrid(x0s, x1s) #está fazendo a distribuição nxn, gerando duas matrizes
    X_ = np.c_[x0.ravel(), x1.ravel()] #c_ = cópia
    ypred  = clf.predict(X_).reshape(x0.shape)
    plt.contourf(x0,x1,ypred,cmap=plt.cm.brg, alpha=0.2)

# %% [markdown]
# A seguir, criaremos a classe MLP com Keras.
#
# Note que o predict praticamente não mudou desde a última atividade, porém, o fit está totalmente adaptado ao uso da biblioteca do Keras.
# Mantive os parâmetros básicos de configuração da rede. Achei muito útil o uso do parâmetro use_multiprocessing=True no fit do modelo. Acelerou bem o tempo de treinamento.
#
# O passo a passo de definição da rede segue basicamente o mesmo que vimos em sala de aula:<br>
# 1 - Faz o yhot_encode dos doados de entrada <br>
# 2 - InputLayer com quantidade de neurônios conforme a quantidade de características base de dados<br>
# 3 - Adiciona as camadas intermediárias conforme parametrização passando a função de ativação parametrizada<br>
# 4 - Como precisamos construir uma rede tal que possa processar tanto bases binárias quanto multiclasse, precisamos observar que a definição da quatidade de neurônios da última camada deve ser conforme a base de dados. A função de ativação softmax pode ser usada em ambos casos, portanto foi escolhida.<br>
# 5 - Chama o fit<br>

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
import numpy as np
from tensorflow import keras
from keras import layers
from tensorflow.keras.utils import to_categorical

class MLPKerasClassifier(BaseEstimator, ClassifierMixin):
    '''
    Rede neural para classificação utilizando Keras.
    '''
    def __init__(self, n_hidden=[5,4], activation_function='relu', epochs=1000, verbose=0, callbacks=[]):
        self.n_hidden = n_hidden
        self.activation_function = activation_function
        self.epochs = epochs
        self.verbose = verbose
        self.callbacks = callbacks
    
    def fit(self, X, y):
        #adicionar ao self no final
        self.labels,ids = np.unique(y,return_inverse=True)
        
        #tratando caso binario ou multiclasse
        yhot = keras.utils.to_categorical(ids)
        size_last_layer = yhot.shape[1]
        size_first_layer = X.shape[1]
        
        if len(self.n_hidden) == 0:
            raise Exception('Parâmetro inválido: n_hidden!')
        else:
            #inicia o modelo
            model = keras.models.Sequential()
            model.add(layers.InputLayer(input_shape=(size_first_layer,)))

            #para cada elemento da lista, adicionar uma camada densa com a quantidade de neurônios conforme valor.
            for idx in range(len(self.n_hidden)):
                value = self.n_hidden[idx]
                model.add(layers.Dense(value, activation=self.activation_function))

            #na última camada, função softmax pra ser capaz de classificar bases binárias ou multiclasse
            model.add(layers.Dense(size_last_layer,activation='softmax'))

            model.compile(optimizer="rmsprop",
                            loss='categorical_crossentropy', #precisa ser categorial_... porque a base pode ser multiclasse
                            metrics=['accuracy'])
            
            model.fit(X,yhot,epochs=self.epochs,use_multiprocessing=True, verbose=self.verbose, callbacks=self.callbacks)
            self.coef_ = model.get_weights() 
            
            #salva o modelo
            self.model = model
        

    def predict(self, X, y=None):
        a = self.model.predict(X)
        idx = np.argmax(a, axis=1)
        ypred = self.labels[idx]
        return ypred

# %% [markdown]
# ### Otimizando parâmetros para SVM, LogisticRegression, RandomForest e KNN
#
# Testaremos otimizar os parâmetros para estes dois classificadores e depois utilizá-lo em um stacking no final.

# %%
#separando parte da base de treino e teste para validação do modelo e otimização de parâmetros
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((668, 13), (223, 13), (668, 1), (223, 1))

# %%
#Construindo um stacking de RandomForest aplicando GridSerach para otimizar os parâmetros do classficiador e utilizar no final
from sklearn.metrics import make_scorer, mean_squared_error

def BuildTestModel(model, parameters, x_tr, y_tr):
    '''
    Recebe um modelo de classificador e os parâmetros desejados para otimizar no parâmetro. Constroi o modelo, oferece a acuracia e retorna o modelo.
    '''
    pipetotal = Pipeline([
        ('atributosDesejados', AtributosDesejados()),
        ('trataAtributos', trataAtributos),
        ('classificador', model)
    ])

    parametros = dict()
    parametros['atributosDesejados__excluirName'] = [True]
    parametros['atributosDesejados__excluirCabin'] = [False]
    parametros['atributosDesejados__excluirSobrenome'] = [False]
    
    for i in range(len(parameters)):
        parametros['classificador__' + parameters[i][0]] = parameters[i][1]

    modelo = GridSearchCV(pipetotal, param_grid=parametros)
    #modelo = pipetotal
    modelo.fit(x_tr, y_tr)

    #scores = cross_validate(modelo, x_tr, y_tr, cv=RepeatedKFold(n_repeats=10))
    scores = cross_validate(modelo, x_tr, y_tr)
    
    print("Score médio:", np.mean(scores['test_score']), "\nDesvio P.:", np.std(scores['test_score']))

    return modelo

# %% [markdown]
# ### Treinando o
#
# Caso queira-se buscar melhores valores nos parâmetros da rede MLP, pode-se destacá-los para serem chamados no GridSearch conforme abaixo por meio da lista de parâmetros em parMLP.
# Além disso, passamos também como opção, função de callback EarlyStopping para parar o treinamento da rede caso a acurácia caia duas vezes consecutivas.

# %%
parMLP = []
#parMLP.append(['C', [0.1, 1, 2]]) 
#parMLP.append(['gamma', [0.01,0.001]])
#parMLP.append(['kernel', ['rbf', 'poly', 'sigmoid']])


callbacks_list = [
    keras.callbacks.EarlyStopping(
    monitor="accuracy", #função a ser considerada no monitoramento para pararmos o treinamento
    patience=2)#,     #se aumentar a acurácia de validação duas vezes ele para

    #keras.callbacks.ModelCheckpoint(filepath="checkpoint_path.keras",
    #                            monitor="val_loss",
    #                            save_best_only=True)
]

modMLP = BuildTestModel(MLPKerasClassifier(n_hidden=[16,8], activation_function='relu', epochs=1000, verbose=1, callbacks=callbacks_list), parMLP, X_train, y_train)

#caso utilize GridSearch
modMLP.best_params_
modMLP.best_estimator_
# Out:
# Epoch 1/1000
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6569 - accuracy: 0.6629
# Epoch 2/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6185 - accuracy: 0.7116
# Epoch 3/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5851 - accuracy: 0.7453
# Epoch 4/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5532 - accuracy: 0.7809
# Epoch 5/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5223 - accuracy: 0.8090
# Epoch 6/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4920 - accuracy: 0.8333
# Epoch 7/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4637 - accuracy: 0.8483
# Epoch 8/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.8464
# Epoch 9/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4180 - accuracy: 0.8614
# Epoch 10/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8521
# Epoch 11/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8558
# Epoch 1/1000
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6616 - accuracy: 0.7004
# Epoch 2/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6186 - accuracy: 0.7397
# Epoch 3/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5805 - accuracy: 0.7584
# Epoch 4/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.7790
# Epoch 5/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.8052
# Epoch 6/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4736 - accuracy: 0.8090
# Epoch 7/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8165
# Epoch 8/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4282 - accuracy: 0.8202
# Epoch 9/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.8352
# Epoch 10/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8427
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3855 - accuracy: 0.8427
# Epoch 12/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8483
# Epoch 13/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8577
# Epoch 14/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8614
# Epoch 15/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8670
# Epoch 16/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3317 - accuracy: 0.8727
# Epoch 17/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3211 - accuracy: 0.8839
# Epoch 18/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3115 - accuracy: 0.8839
# Epoch 19/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3018 - accuracy: 0.8858
# Epoch 20/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.9007
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.9064
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2724 - accuracy: 0.9082
# Epoch 23/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.9101
# Epoch 24/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.9176
# Epoch 25/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9195
# Epoch 26/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9213
# Epoch 27/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.9232
# Epoch 28/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9270
# Epoch 29/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9307
# Epoch 30/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9307
# Epoch 31/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.9363
# Epoch 32/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1563 - accuracy: 0.9476
# Epoch 33/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1434 - accuracy: 0.9494
# Epoch 34/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1307 - accuracy: 0.9569
# Epoch 35/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9569
# Epoch 36/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 0.9569
# Epoch 1/1000
# 17/17 [==============================] - 1s 3ms/step - loss: 0.6555 - accuracy: 0.7022
# Epoch 2/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5931 - accuracy: 0.7959
# Epoch 3/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5402 - accuracy: 0.8221
# Epoch 4/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4943 - accuracy: 0.8165
# Epoch 5/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4571 - accuracy: 0.8258
# Epoch 6/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4292 - accuracy: 0.8371
# Epoch 7/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4085 - accuracy: 0.8390
# Epoch 8/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8446
# Epoch 9/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3796 - accuracy: 0.8558
# Epoch 10/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8539
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3572 - accuracy: 0.8652
# Epoch 12/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3470 - accuracy: 0.8670
# Epoch 13/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3359 - accuracy: 0.8801
# Epoch 14/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3258 - accuracy: 0.8895
# Epoch 15/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3170 - accuracy: 0.8895
# Epoch 16/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3070 - accuracy: 0.8933
# Epoch 17/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2969 - accuracy: 0.9026
# Epoch 18/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2884 - accuracy: 0.8914
# Epoch 19/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2790 - accuracy: 0.9120
# Epoch 20/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2691 - accuracy: 0.9139
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2595 - accuracy: 0.9176
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2500 - accuracy: 0.9176
# Epoch 23/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9213
# Epoch 24/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2305 - accuracy: 0.9251
# Epoch 25/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.9251
# Epoch 26/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2096 - accuracy: 0.9270
# Epoch 27/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1998 - accuracy: 0.9307
# Epoch 28/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9345
# Epoch 29/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9326
# Epoch 30/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1694 - accuracy: 0.9363
# Epoch 31/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1600 - accuracy: 0.9382
# Epoch 32/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9382
# Epoch 33/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.9419
# Epoch 34/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9513
# Epoch 35/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.9532
# Epoch 36/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9551
# Epoch 37/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9625
# Epoch 38/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.9663
# Epoch 39/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9682
# Epoch 40/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9775
# Epoch 41/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9757
# Epoch 42/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9831
# Epoch 43/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9831
# Epoch 44/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9869
# Epoch 45/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9906
# Epoch 46/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9925
# Epoch 47/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.9944
# Epoch 48/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9963
# Epoch 49/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0313 - accuracy: 0.9925
# Epoch 50/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9944
# Epoch 1/1000
# 17/17 [==============================] - 1s 3ms/step - loss: 0.6745 - accuracy: 0.6206
# Epoch 2/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.7308
# Epoch 3/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6045 - accuracy: 0.7477
# Epoch 4/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5685 - accuracy: 0.7664
# Epoch 5/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.7794
# Epoch 6/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7944
# Epoch 7/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.8224
# Epoch 8/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8355
# Epoch 9/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.8393
# Epoch 10/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4064 - accuracy: 0.8505
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3930 - accuracy: 0.8467
# Epoch 12/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3804 - accuracy: 0.8542
# Epoch 13/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8598
# Epoch 14/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3574 - accuracy: 0.8598
# Epoch 15/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3471 - accuracy: 0.8673
# Epoch 16/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8692
# Epoch 17/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3269 - accuracy: 0.8860
# Epoch 18/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3176 - accuracy: 0.8916
# Epoch 19/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3073 - accuracy: 0.8916
# Epoch 20/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2978 - accuracy: 0.9047
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2887 - accuracy: 0.9065
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2786 - accuracy: 0.9065
# Epoch 23/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2695 - accuracy: 0.9121
# Epoch 24/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2602 - accuracy: 0.9103
# Epoch 25/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2508 - accuracy: 0.9196
# Epoch 26/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2406 - accuracy: 0.9196
# Epoch 27/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.9271
# Epoch 28/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2217 - accuracy: 0.9290
# Epoch 29/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2122 - accuracy: 0.9308
# Epoch 30/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2015 - accuracy: 0.9308
# Epoch 31/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1914 - accuracy: 0.9383
# Epoch 32/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9383
# Epoch 33/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9439
# Epoch 34/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1585 - accuracy: 0.9495
# Epoch 35/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1497 - accuracy: 0.9551
# Epoch 36/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1398 - accuracy: 0.9570
# Epoch 37/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9607
# Epoch 38/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9626
# Epoch 39/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9645
# Epoch 40/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1044 - accuracy: 0.9645
# Epoch 41/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9645
# Epoch 1/1000
# 17/17 [==============================] - 1s 3ms/step - loss: 0.6755 - accuracy: 0.5757
# Epoch 2/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6056 - accuracy: 0.7794
# Epoch 3/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5478 - accuracy: 0.7981
# Epoch 4/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5004 - accuracy: 0.8262
# Epoch 5/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.8505
# Epoch 6/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4301 - accuracy: 0.8486
# Epoch 7/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8523
# Epoch 8/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8542
# Epoch 9/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8579
# Epoch 10/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8654
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3552 - accuracy: 0.8673
# Epoch 12/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8822
# Epoch 13/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3334 - accuracy: 0.8748
# Epoch 14/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3237 - accuracy: 0.8804
# Epoch 1/1000
# 21/21 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6677
# Epoch 2/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5607 - accuracy: 0.7096
# Epoch 3/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5124 - accuracy: 0.7515
# Epoch 4/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4744 - accuracy: 0.7964
# Epoch 5/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.8353
# Epoch 6/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8338
# Epoch 7/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8368
# Epoch 8/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8383
# Epoch 9/1000
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3790 - accuracy: 0.8458
# Epoch 10/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.8503
# Epoch 11/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8563
# Epoch 12/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.8593
# Epoch 13/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8638
# Epoch 14/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3249 - accuracy: 0.8698
# Epoch 15/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3134 - accuracy: 0.8802
# Epoch 16/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8832
# Epoch 17/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2898 - accuracy: 0.8877
# Epoch 18/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2787 - accuracy: 0.8967
# Epoch 19/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2662 - accuracy: 0.9027
# Epoch 20/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2522 - accuracy: 0.9072
# Epoch 21/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2385 - accuracy: 0.9162
# Epoch 22/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2246 - accuracy: 0.9207
# Epoch 23/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2114 - accuracy: 0.9251
# Epoch 24/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1966 - accuracy: 0.9222
# Epoch 25/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1830 - accuracy: 0.9341
# Epoch 26/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1697 - accuracy: 0.9341
# Epoch 27/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1559 - accuracy: 0.9401
# Epoch 28/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1435 - accuracy: 0.9431
# Epoch 29/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9536
# Epoch 30/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9596
# Epoch 31/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9641
# Epoch 32/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9731
# Epoch 33/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9790
# Epoch 34/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9775
# Epoch 35/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9895
# Epoch 36/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9865
# Epoch 37/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9865
# Epoch 1/1000
# 14/14 [==============================] - 1s 2ms/step - loss: 0.6643 - accuracy: 0.6557
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6126 - accuracy: 0.6885
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7260
# Epoch 4/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7705
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4991 - accuracy: 0.7963
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4706 - accuracy: 0.8150
# Epoch 7/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.8314
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8384
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8431
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3931 - accuracy: 0.8431
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3796 - accuracy: 0.8571
# Epoch 12/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8595
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.8759
# Epoch 14/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8759
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3297 - accuracy: 0.8899
# Epoch 16/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8899
# Epoch 17/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3065 - accuracy: 0.8946
# Epoch 18/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2975 - accuracy: 0.9040
# Epoch 19/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2853 - accuracy: 0.9016
# Epoch 20/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2751 - accuracy: 0.9063
# Epoch 21/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2643 - accuracy: 0.9063
# Epoch 22/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9110
# Epoch 23/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2426 - accuracy: 0.9157
# Epoch 24/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2307 - accuracy: 0.9110
# Epoch 25/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.9157
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6457 - accuracy: 0.6956
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5815 - accuracy: 0.7775
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5288 - accuracy: 0.8080
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4895 - accuracy: 0.7986
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4609 - accuracy: 0.8173
# Epoch 6/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4387 - accuracy: 0.8220
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4192 - accuracy: 0.8290
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8384
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3906 - accuracy: 0.8454
# Epoch 10/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3785 - accuracy: 0.8548
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.8478
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.8665
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3460 - accuracy: 0.8712
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3347 - accuracy: 0.8806
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3250 - accuracy: 0.8852
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3154 - accuracy: 0.8852
# Epoch 17/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3047 - accuracy: 0.8876
# Epoch 18/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2942 - accuracy: 0.8970
# Epoch 19/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.8993
# Epoch 20/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2740 - accuracy: 0.8993
# Epoch 21/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2634 - accuracy: 0.9087
# Epoch 22/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2527 - accuracy: 0.9133
# Epoch 23/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9180
# Epoch 24/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2304 - accuracy: 0.9180
# Epoch 25/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2195 - accuracy: 0.9180
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6350 - accuracy: 0.7049
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5797 - accuracy: 0.7658
# Epoch 3/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5396 - accuracy: 0.7681
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5052 - accuracy: 0.8033
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4743 - accuracy: 0.8314
# Epoch 6/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8454
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.8501
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8618
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3842 - accuracy: 0.8759
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3669 - accuracy: 0.8735
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3523 - accuracy: 0.8759
# Epoch 1/1000
# 14/14 [==============================] - 1s 4ms/step - loss: 0.6608 - accuracy: 0.6206
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6157 - accuracy: 0.6206
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.6347
# Epoch 4/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.6815
# Epoch 5/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5157 - accuracy: 0.7564
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4915 - accuracy: 0.7963
# Epoch 7/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.8337
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4504 - accuracy: 0.8665
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.8689
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4139 - accuracy: 0.8806
# Epoch 11/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.8759
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3815 - accuracy: 0.8852
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3681 - accuracy: 0.8782
# Epoch 14/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3567 - accuracy: 0.8806
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6565 - accuracy: 0.7220
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6212 - accuracy: 0.7734
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5887 - accuracy: 0.7780
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5571 - accuracy: 0.8131
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5252 - accuracy: 0.8248
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4985 - accuracy: 0.8248
# Epoch 7/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.8318
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.8201
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4379 - accuracy: 0.8388
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4240 - accuracy: 0.8271
# Epoch 11/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4109 - accuracy: 0.8341
# Epoch 1/1000
# 17/17 [==============================] - 1s 3ms/step - loss: 0.6737 - accuracy: 0.6011
# Epoch 2/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.6217
# Epoch 3/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5893 - accuracy: 0.6217
# Epoch 4/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5554 - accuracy: 0.6573
# Epoch 5/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5259 - accuracy: 0.7434
# Epoch 6/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5002 - accuracy: 0.7996
# Epoch 7/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4777 - accuracy: 0.8240
# Epoch 8/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.8427
# Epoch 9/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.8614
# Epoch 10/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.8652
# Epoch 11/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8670
# Epoch 12/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3852 - accuracy: 0.8633
# Epoch 13/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3699 - accuracy: 0.8614
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6955 - accuracy: 0.5386
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6432 - accuracy: 0.7119
# Epoch 3/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5981 - accuracy: 0.7541
# Epoch 4/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5590 - accuracy: 0.7822
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.7986
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4954 - accuracy: 0.8267
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4699 - accuracy: 0.8314
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4477 - accuracy: 0.8525
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4281 - accuracy: 0.8665
# Epoch 10/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4120 - accuracy: 0.8642
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3969 - accuracy: 0.8759
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8782
# Epoch 13/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3705 - accuracy: 0.8735
# Epoch 14/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3587 - accuracy: 0.8852
# Epoch 15/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8923
# Epoch 16/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8852
# Epoch 17/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3223 - accuracy: 0.8946
# Epoch 18/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3104 - accuracy: 0.9016
# Epoch 19/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3002 - accuracy: 0.8993
# Epoch 20/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2883 - accuracy: 0.8970
# Epoch 1/1000
# 14/14 [==============================] - 1s 4ms/step - loss: 0.6738 - accuracy: 0.6932
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.7190
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6131 - accuracy: 0.7564
# Epoch 4/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5833 - accuracy: 0.7635
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.7728
# Epoch 6/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5223 - accuracy: 0.7963
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4935 - accuracy: 0.8173
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4660 - accuracy: 0.8290
# Epoch 9/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.8454
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4229 - accuracy: 0.8618
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8689
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.8735
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8618
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.8665
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.6651
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6407 - accuracy: 0.7073
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6066 - accuracy: 0.7283
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5727 - accuracy: 0.7471
# Epoch 5/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5392 - accuracy: 0.7775
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4795 - accuracy: 0.8314
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.8361
# Epoch 9/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.8384
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.8337
# Epoch 11/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8314
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6631 - accuracy: 0.6440
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6226 - accuracy: 0.7518
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.7681
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5502 - accuracy: 0.7916
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5175 - accuracy: 0.8080
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4867 - accuracy: 0.8220
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4588 - accuracy: 0.8290
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.8525
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.8618
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3961 - accuracy: 0.8618
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8665
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3715 - accuracy: 0.8782
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.8759
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3516 - accuracy: 0.8829
# Epoch 15/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3432 - accuracy: 0.8852
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3337 - accuracy: 0.8876
# Epoch 17/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3265 - accuracy: 0.8899
# Epoch 18/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.8970
# Epoch 19/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3108 - accuracy: 0.8970
# Epoch 20/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.8993
# Epoch 21/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2940 - accuracy: 0.9063
# Epoch 22/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2862 - accuracy: 0.9087
# Epoch 23/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2789 - accuracy: 0.9133
# Epoch 24/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.9180
# Epoch 25/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2618 - accuracy: 0.9227
# Epoch 26/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2530 - accuracy: 0.9251
# Epoch 27/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2446 - accuracy: 0.9274
# Epoch 28/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2369 - accuracy: 0.9251
# Epoch 29/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9274
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6503 - accuracy: 0.7103
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 0.7383
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5745 - accuracy: 0.7500
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.7827
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5272 - accuracy: 0.7874
# Epoch 6/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.8084
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4896 - accuracy: 0.8154
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8388
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4574 - accuracy: 0.8294
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.8341
# Epoch 1/1000
# 17/17 [==============================] - 1s 3ms/step - loss: 0.6579 - accuracy: 0.6629
# Epoch 2/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.7285
# Epoch 3/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5566 - accuracy: 0.7697
# Epoch 4/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.8071
# Epoch 5/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4844 - accuracy: 0.8221
# Epoch 6/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.8296
# Epoch 7/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4410 - accuracy: 0.8427
# Epoch 8/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4225 - accuracy: 0.8371
# Epoch 9/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4050 - accuracy: 0.8446
# Epoch 10/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.8446
# Epoch 11/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8558
# Epoch 12/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8539
# Epoch 13/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3501 - accuracy: 0.8596
# Epoch 14/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8689
# Epoch 15/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3237 - accuracy: 0.8708
# Epoch 16/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3112 - accuracy: 0.8801
# Epoch 17/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2974 - accuracy: 0.8839
# Epoch 18/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8895
# Epoch 19/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2706 - accuracy: 0.9007
# Epoch 20/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.9007
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2422 - accuracy: 0.9120
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2296 - accuracy: 0.9195
# Epoch 23/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.9195
# Epoch 24/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.9288
# Epoch 25/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1862 - accuracy: 0.9307
# Epoch 26/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1719 - accuracy: 0.9363
# Epoch 27/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9401
# Epoch 28/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9457
# Epoch 29/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1320 - accuracy: 0.9569
# Epoch 30/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 0.9588
# Epoch 31/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9700
# Epoch 32/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.9775
# Epoch 33/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9775
# Epoch 34/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9794
# Epoch 35/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0733 - accuracy: 0.9813
# Epoch 36/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9850
# Epoch 37/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9850
# Epoch 38/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0548 - accuracy: 0.9888
# Epoch 39/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9869
# Epoch 40/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0447 - accuracy: 0.9888
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6838 - accuracy: 0.4824
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6427 - accuracy: 0.7143
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6218 - accuracy: 0.7635
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6029 - accuracy: 0.8009
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.8033
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5703 - accuracy: 0.8220
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5563 - accuracy: 0.8501
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.8407
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5289 - accuracy: 0.8595
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5149 - accuracy: 0.8642
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4991 - accuracy: 0.8595
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4834 - accuracy: 0.8665
# Epoch 13/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4658 - accuracy: 0.8712
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.8806
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4164 - accuracy: 0.8876
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8923
# Epoch 17/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3635 - accuracy: 0.8970
# Epoch 18/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3428 - accuracy: 0.9016
# Epoch 19/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.9016
# Epoch 20/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.9040
# Epoch 21/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2988 - accuracy: 0.9087
# Epoch 22/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2869 - accuracy: 0.9133
# Epoch 23/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.9180
# Epoch 24/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2687 - accuracy: 0.9204
# Epoch 25/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2606 - accuracy: 0.9274
# Epoch 26/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2532 - accuracy: 0.9274
# Epoch 27/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.9297
# Epoch 28/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9297
# Epoch 29/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.9368
# Epoch 30/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2266 - accuracy: 0.9344
# Epoch 31/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2197 - accuracy: 0.9415
# Epoch 32/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2127 - accuracy: 0.9415
# Epoch 33/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9438
# Epoch 34/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1996 - accuracy: 0.9438
# Epoch 35/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1926 - accuracy: 0.9438
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6660 - accuracy: 0.6183
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6327 - accuracy: 0.6230
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6026 - accuracy: 0.6347
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5729 - accuracy: 0.6581
# Epoch 5/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5472 - accuracy: 0.7119
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5227 - accuracy: 0.7400
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5001 - accuracy: 0.7611
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4803 - accuracy: 0.8033
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4611 - accuracy: 0.8173
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4436 - accuracy: 0.8431
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4275 - accuracy: 0.8595
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4143 - accuracy: 0.8618
# Epoch 13/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8571
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3879 - accuracy: 0.8642
# Epoch 15/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8642
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3656 - accuracy: 0.8689
# Epoch 17/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8642
# Epoch 18/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3440 - accuracy: 0.8618
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6496 - accuracy: 0.6183
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.6276
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5666 - accuracy: 0.6417
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5383 - accuracy: 0.6838
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5155 - accuracy: 0.7354
# Epoch 6/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4947 - accuracy: 0.7681
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4764 - accuracy: 0.7916
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.8361
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.8407
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4288 - accuracy: 0.8501
# Epoch 11/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4129 - accuracy: 0.8548
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3973 - accuracy: 0.8571
# ...
# Epoch 22/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2452 - accuracy: 0.9084
# Epoch 23/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2326 - accuracy: 0.9103
# Epoch 24/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.9159
# Epoch 25/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2076 - accuracy: 0.9196
# Epoch 26/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1931 - accuracy: 0.9290
# Epoch 27/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9308
# Epoch 28/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1667 - accuracy: 0.9402
# Epoch 29/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1536 - accuracy: 0.9458
# Epoch 30/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1415 - accuracy: 0.9589
# Epoch 31/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1286 - accuracy: 0.9589
# Epoch 32/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1168 - accuracy: 0.9645
# Epoch 33/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9738
# Epoch 34/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9813
# Epoch 35/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9850
# Epoch 36/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9850
# Epoch 37/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9869
# Epoch 38/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0631 - accuracy: 0.9907
# Epoch 39/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9907
# Epoch 40/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0509 - accuracy: 0.9925
# Epoch 41/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9925
# Epoch 42/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 0.9925
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6851 - accuracy: 0.5818
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6413 - accuracy: 0.6332
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6102 - accuracy: 0.6379
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5826 - accuracy: 0.6589
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5557 - accuracy: 0.6986
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5307 - accuracy: 0.7383
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5076 - accuracy: 0.7780
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4857 - accuracy: 0.8248
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.8388
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4463 - accuracy: 0.8481
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4301 - accuracy: 0.8621
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4147 - accuracy: 0.8668
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.8692
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3876 - accuracy: 0.8738
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3762 - accuracy: 0.8832
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8738
# Epoch 17/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8762
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6700 - accuracy: 0.6192
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6227 - accuracy: 0.6636
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.7009
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5511 - accuracy: 0.7313
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5205 - accuracy: 0.7757
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4919 - accuracy: 0.7944
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4670 - accuracy: 0.8178
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4473 - accuracy: 0.8364
# Epoch 9/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4278 - accuracy: 0.8481
# Epoch 10/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4123 - accuracy: 0.8551
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3983 - accuracy: 0.8621
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3854 - accuracy: 0.8645
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3729 - accuracy: 0.8692
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.8668
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 0.8715
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3400 - accuracy: 0.8832
# Epoch 17/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3281 - accuracy: 0.8832
# Epoch 18/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3187 - accuracy: 0.8902
# Epoch 19/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3082 - accuracy: 0.8902
# Epoch 20/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2979 - accuracy: 0.8949
# Epoch 21/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2877 - accuracy: 0.8995
# Epoch 22/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2771 - accuracy: 0.8972
# Epoch 23/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2661 - accuracy: 0.9042
# Epoch 24/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2558 - accuracy: 0.9112
# Epoch 25/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2445 - accuracy: 0.9112
# Epoch 26/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2354 - accuracy: 0.9159
# Epoch 27/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2238 - accuracy: 0.9229
# Epoch 28/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2127 - accuracy: 0.9299
# Epoch 29/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2021 - accuracy: 0.9276
# Epoch 30/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1897 - accuracy: 0.9416
# Epoch 31/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1760 - accuracy: 0.9439
# Epoch 32/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1631 - accuracy: 0.9463
# Epoch 33/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1526 - accuracy: 0.9509
# Epoch 34/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1410 - accuracy: 0.9579
# Epoch 35/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9650
# Epoch 36/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1219 - accuracy: 0.9650
# Epoch 37/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1132 - accuracy: 0.9696
# Epoch 38/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1031 - accuracy: 0.9766
# Epoch 39/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9813
# Epoch 40/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 0.9813
# Epoch 41/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9860
# Epoch 42/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0736 - accuracy: 0.9907
# Epoch 43/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9907
# Epoch 44/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 0.9836
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6981 - accuracy: 0.5164
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6510 - accuracy: 0.6963
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6153 - accuracy: 0.7266
# Epoch 4/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5812 - accuracy: 0.7617
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5502 - accuracy: 0.7780
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5198 - accuracy: 0.8224
# Epoch 7/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4928 - accuracy: 0.8248
# Epoch 8/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4676 - accuracy: 0.8411
# Epoch 9/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4459 - accuracy: 0.8528
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4268 - accuracy: 0.8551
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.8551
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.8645
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8738
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8738
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3502 - accuracy: 0.8785
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3357 - accuracy: 0.8855
# Epoch 17/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8879
# Epoch 18/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3090 - accuracy: 0.8925
# Epoch 19/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2935 - accuracy: 0.8972
# Epoch 20/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2778 - accuracy: 0.9089
# Epoch 21/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2640 - accuracy: 0.9182
# Epoch 22/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2505 - accuracy: 0.9182
# Epoch 23/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2366 - accuracy: 0.9136
# Epoch 1/1000
# 14/14 [==============================] - 1s 5ms/step - loss: 0.6916 - accuracy: 0.5491
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6596 - accuracy: 0.6869
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.7430
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6075 - accuracy: 0.7617
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5805 - accuracy: 0.7827
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5522 - accuracy: 0.8107
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5255 - accuracy: 0.8341
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5004 - accuracy: 0.8318
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4757 - accuracy: 0.8458
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4542 - accuracy: 0.8458
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.8458
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 0.6858 - accuracy: 0.6332
# Epoch 2/1000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6576 - accuracy: 0.7617
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6309 - accuracy: 0.7921
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6035 - accuracy: 0.8131
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5752 - accuracy: 0.8154
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5456 - accuracy: 0.8201
# Epoch 7/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5177 - accuracy: 0.8154
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4912 - accuracy: 0.8248
# Epoch 9/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4673 - accuracy: 0.8318
# Epoch 10/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4453 - accuracy: 0.8411
# Epoch 11/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4234 - accuracy: 0.8388
# Epoch 12/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4057 - accuracy: 0.8528
# Epoch 13/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3902 - accuracy: 0.8575
# Epoch 14/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3775 - accuracy: 0.8668
# Epoch 15/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3671 - accuracy: 0.8762
# Epoch 16/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3571 - accuracy: 0.8715
# Epoch 17/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3489 - accuracy: 0.8762
# Epoch 1/1000
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6525 - accuracy: 0.7383
# Epoch 2/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5981 - accuracy: 0.7888
# Epoch 3/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5485 - accuracy: 0.8168
# Epoch 4/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.8243
# Epoch 5/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.8336
# Epoch 6/1000
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.8336
# Epoch 7/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4215 - accuracy: 0.8299
# Score médio: 0.8038155089215577
# Desvio P.: 0.048360046663039176
# Pipeline(steps=[('atributosDesejados', AtributosDesejados()),
#                 ('trataAtributos',
#                  Pipeline(steps=[('unecaracteristicas',
#                                   FeatureUnion(transformer_list=[('pipenum',
#                                                                   Pipeline(steps=[('atributos_numericos',
#                                                                                    AtributosNumericos()),
#                                                                                   ('imputer',
#                                                                                    SimpleImputer(strategy='median')),
#                                                                                   ('scaler',
#                                                                                    StandardScaler())])),
#                                                                  ('pipecat',
#                                                                   Pipeline(steps=[('atributos_categoricos',
#                                                                                    AtributosCategoricos()),
#                                                                                   ('imputer',
#                                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                                   ('encoder',
#                                                                                    OneHotEncoder(handle_unknown='ignore'))]))]))])),
#                 ('classificador',
#                  MLPKerasClassifier(callbacks=[<keras.callbacks.EarlyStopping object at 0x7ff1b5780c90>],
#                                     n_hidden=[16, 8], verbose=1))])

# %%
def FitPredictToCsv(model, filename, x_tr, y_tr):
    model.fit(x_tr,y_tr)
    y_pred = model.predict(test)
    s = cross_validate(model, x_tr, y_tr, cv=RepeatedKFold())
    print("SCORE FINAL\nMédio:", np.mean(s['test_score']), "\nDesvio P.:", np.std(s['test_score']))

    result = test[['PassengerId']]
    result['Survived'] = y_pred
    result.to_csv(filename+'.csv',index=False)

def PredictToCsv(model, filename):   
    y_pred = model.predict(test)

    result = test[['PassengerId']]
    result['Survived'] = y_pred
    result.to_csv(filename+'.csv',index=False)

# %%
PredictToCsv(modMLP, "kaggle_submission_v2")
